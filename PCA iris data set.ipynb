# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from mpl_toolkits.mplot3d import Axes3D
import csv
M=[]
# ifile  = open('da.csv', "r")
# read = csv.reader(ifile)
# for row in read :
#     M.append(np.array(row))
# M=np.array(M)
M= np.genfromtxt("da.csv", delimiter=",", skip_header=1)
#print(M)    
c = np.array([[0.00] * 4] *150)
#print(c)
for i in range(150):
    for j in range(4):
        c[i][j]=M[i][j]
print(c)       


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# for i in range(100):
#     d.append(random.choice(N))
#     e.append(random.choice(N))
#     f.append(random.choice(N))
    
    
# g=np.round(d,2)
# h=np.round(e,2)
# j=np.round(f,2)#round a 1D array till two decimal points

# for i in range(1):
#     M.append(g)
#     M.append(h)
#     M.append(j)
M = np.array(M)
#print(M)
#print(M[2,2])
c=c.transpose()
Mcov=np.cov(c)
print("covariance of given matrix: \n",Mcov,"\n")
E,V=np.linalg.eig(Mcov)#E=eigen value,V=eigen vector
print("eigen values are: \n",E,"\n")

#ax.scatter(g, h, j, marker=m)  #rotation and further changing veiwing angles is not available on jupyter
Q=[]
s =[]
t = []
u = []
Q=np.array(V)
x = []
y = []
z = []
for i in range(3):
    x.append(V[i][0])
    y.append(V[i][1])
    z.append(V[i][2])
print("eigen vectors are: \n",Q,"\n")

#M=M.transpose()
print(M)
M2=np.matmul(c,V)

#M2=np.matmul(x,M)
print(M2)

for i in range(100):
    s.append(M2[i][0])
    t.append(M2[i][1])
    u.append(M2[i][2])

#ax.scatter(s, t, u, marker=m)    

plt.show()                     #use interactive python via terminal  for that
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
import pandas
df = pandas.read_csv('da.csv')
print(df)
# Out:
#      sepal len  sepal wid  petal len  petal wid           class
# 0          5.1        3.5        1.4        0.2     Iris-setosa
# 1          4.9        3.0        1.4        0.2     Iris-setosa
# 2          4.7        3.2        1.3        0.2     Iris-setosa
# 3          4.6        3.1        1.5        0.2     Iris-setosa
# 4          5.0        3.6        1.4        0.2     Iris-setosa
# 5          5.4        3.9        1.7        0.4     Iris-setosa
# 6          4.6        3.4        1.4        0.3     Iris-setosa
# 7          5.0        3.4        1.5        0.2     Iris-setosa
# 8          4.4        2.9        1.4        0.2     Iris-setosa
# 9          4.9        3.1        1.5        0.1     Iris-setosa
# 10         5.4        3.7        1.5        0.2     Iris-setosa
# 11         4.8        3.4        1.6        0.2     Iris-setosa
# 12         4.8        3.0        1.4        0.1     Iris-setosa
# 13         4.3        3.0        1.1        0.1     Iris-setosa
# ...

# %% [markdown]
# ##  PCA IRIS DATA SET

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from mpl_toolkits.mplot3d import Axes3D
import csv
M=[]
M= np.genfromtxt("da.csv", delimiter=",", skip_header=1)
c = np.array([[0.00] * 4] *150)
v = np.array([[0.0000]*4]*3)

for i in range(150):
    for j in range(4):
        c[i][j]=M[i][j]
print("reduced data set with sepal length/width, petal length/width")
print(c)   
c=c.transpose()
Mcov=np.cov(c)
print("\ncovariance of given matrix: \n",Mcov,"\n")
E,V=np.linalg.eig(Mcov)#E=eigen value,V=eigen vector
print("eigen values are: \n",E,"\n")
print("eigen vectors are: \n",V,"\n")

for i in range(3):
    for j in range(4):
        v[i][j]=V[i][j]
print("three vectors chosen for PCA:\n",v,"\n")
M2=np.matmul(v,c)
M2=M2.transpose()
print(M2)

s = []
t = []
u = []
for i in range(50):
    s.append(M2[i][0])
    t.append(M2[i][1])
    u.append(M2[i][2])
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(s, t, u)

x = []
y = []
z = []
for i in range(50):
    x.append(M2[i+50][0])
    y.append(M2[i+50][1])
    z.append(M2[i+50][2])
ax.scatter(x,y,z)

a = []
b = []
c = []

for i in range(50):
    a.append(M2[i+100][0])
    b.append(M2[i+100][1])
    c.append(M2[i+100][2])

ax.scatter(a,b,c)
plt.show()
# Out:
# reduced data set with sepal length/width, petal length/width
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
# ...
